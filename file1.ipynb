# %%
# employe management system

# %%
import pymysql
import tkinter

# %%
# create database

# %%
# import pymysql
# conn=pymysql.connect(user='root',host='localhost',password='Root@123')
# qur='CREATE DATABASE emp_project'
# mycur=conn.cursor()
# mycur.execute(qur)
# mycur.close()
# conn.close()

# %%
# create table

# %%
# import pymysql
# conn=pymysql.connect(user='root',host='localhost',password='Root@123')
# qur='''CREATE TABLE emp (
#     emp_id VARCHAR(10) PRIMARY KEY,
#     emp_name VARCHAR(100),
#     mob_no VARCHAR(15),
#     dept VARCHAR(15),
#     emp_salary VARCHAR(20)
#     )'''
# mycur=conn.cursor()
# mycur.execute(qur)
# mycur.close()
# conn.close()

# %%
# graphical user intrface (GUI)

# %%
import pymysql
from tkinter import *
from tkinter import messagebox
from tkinter import ttk


win=Tk()
win.title('EMPLOYE MANAGMENT SYSTEM')
win.config(bg='grey')
win.geometry('800x600')

def add():
    pass



def show():
    pass



def salary():
    pass


def delete():
    pass

def select():
    pass

def update():
    pass

def clear():
    pass



#main label

l0=Label(win,text='EMPLOYE MANAGMENT SYSTEM',width=40,bg='white',
         fg='black',bd=5,relief='ridge',font=('times new roman',18,'bold'))

l0.place(x=268,y=20)

# emp_id label and entry

l1=Label(win,text='EMPLOYE ID',width=20,bg='white',
         fg='black',bd=5,relief='ridge',font=('times new roman',12,'bold'))

l1.place(x=100,y=80)

id1=StringVar()
e1=Entry(win,width=40,bg='white',fg='black',textvariable=id1,
         bd=5,relief='ridge',font=('times new roman',12,'bold'))

e1.place(x=310,y=80)

# emp_name label and entry

l2=Label(win,text='EMPLOYE NAME',width=20,bg='white',
         fg='black',bd=5,relief='ridge',font=('times new roman',12,'bold'))

l2.place(x=100,y=120)

n1=StringVar()
e2=Entry(win,width=40,bg='white',fg='black',textvariable=n1,
         bd=5,relief='ridge',font=('times new roman',12,'bold'))

e2.place(x=310,y=120)

# MOB NUM label and entry

l3=Label(win,text='MOBILE NUMBER',width=20,bg='white',
         fg='black',bd=5,relief='ridge',font=('times new roman',12,'bold'))

l3.place(x=100,y=160)

M1=StringVar()
e3=Entry(win,width=40,bg='white',fg='black',textvariable=n1,
         bd=5,relief='ridge',font=('times new roman',12,'bold'))

e3.place(x=310,y=160)

# DEPT label entry

l4=Label(win,text='DEPARTMENT',width=20,bg='white',
         fg='black',bd=5,relief='ridge',font=('times new roman',12,'bold'))

l4.place(x=100,y=200)

d1=StringVar()
e4=ttk.Combobox(win,width=40,textvariable=d1,font=('times new roman',12,'bold'))

e4.place(x=310,y=200,height=30)
e4['values']=('R&D','Marketing','Production','HR')
e4.current(0)

#EMP_SALARY label and entry

l5=Label(win,text='SALARY',width=20,bg='white',
         fg='black',bd=5,relief='ridge',font=('times new roman',12,'bold'))

l5.place(x=100,y=240)

s1=StringVar()
e5=Entry(win,width=40,bg='white',fg='black',textvariable=s1,
         bd=5,relief='ridge',font=('times new roman',12,'bold'))

e5.place(x=310,y=240)


# 4 button >> addd show exit salary

b1=Button(win,text='SHOW',width=12,command=show,bd=5,relief='ridge',
          bg='black',fg='white',font=('times new roman',11,'bold'))
b1.place(x=180,y=300)

b2=Button(win,text='ADD',width=12,command=add,bd=5,relief='ridge',
          bg='black',fg='white',font=('times new roman',11,'bold'))
b2.place(x=410,y=300)


b3=Button(win,text='EXIT',width=12,command=win.destroy,bd=5,relief='ridge',
          bg='black',fg='white',font=('times new roman',11,'bold'))
b3.place(x=180,y=340)

b4=Button(win,text='SALARY',width=12,command=salary,bd=5,relief='ridge',
          bg='black',fg='white',font=('times new roman',11,'bold'))
b4.place(x=410,y=340)

# delete interface
# label entry buttonn

l6=Label(win,text='EMPLOYE ID>>',bg='white',fg='black'
         ,width=12,bd=5,font=('times new roman',12,'bold'),relief='ridge')

l6.place(x=100,y=400)

var1=StringVar
e6=Entry(win,textvariable=var1,bg='white',fg='black',width=20,bd=5
         ,font=('times new roman',12,'bold'),relief='ridge')
e6.place(x=310,y=400)

b5=Button(win,text='DELETE',command=delete,fg='white',bg='black',width=12,bd=5
         ,font=('times new roman',12,'bold'),relief='ridge')
b5.place(x=310,y=440)


# update interface
# label entry select and update button


l7=Label(win,text='ENTER ID >> ',bg='white',fg='black'
         ,width=20,bd=5,font=('times new roman',12,'bold'),relief='ridge')

l7.place(x=100,y=490)

var2=StringVar
e7=Entry(win,textvariable=var2,bg='white',fg='black',width=40,bd=5
         ,font=('times new roman',12,'bold'),relief='ridge')
e7.place(x=310,y=490)

b6=Button(win,text='SELECT',command=select,fg='white',bg='black',width=12,bd=5
         ,font=('times new roman',12,'bold'),relief='ridge')
b6.place(x=200,y=540)

b7=Button(win,text='UPDATE',command=update,fg='white',bg='black',width=12,bd=5
         ,font=('times new roman',12,'bold'),relief='ridge')
b7.place(x=350,y=540)

# tree view

treev=ttk.Treeview(win,height=30)
treev.place(x=700,y=80,width=600)

treev["columns"]=("1","2","3","4","5")
treev['show']='headings'

treev.column("1",width=90,anchor='c')
treev.column("2",width=90,anchor='se')
treev.column("3",width=90,anchor='se')
treev.column("4",width=90,anchor='se')
treev.column("5",width=90,anchor='se')

treev.heading("1",text="Emp_ID")
treev.heading("2",text="Emp_Name")
treev.heading("3",text="Mob No")
treev.heading("4",text="Dept")
treev.heading("5",text="Salary")

b8=Button(win,text='CLEAR',width=12,command=clear,bg='black',
          fg='white',font=('times new roman',12,'bold'))
b8.place(x=950,y=710)
win.mainloop()
